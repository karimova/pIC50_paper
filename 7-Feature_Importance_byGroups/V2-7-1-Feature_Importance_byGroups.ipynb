# %% [markdown]
# # 0. Libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from feature_engine.imputation import MeanMedianImputer
from feature_engine.selection import DropConstantFeatures, SmartCorrelatedSelection, DropDuplicateFeatures
from feature_engine.outliers import Winsorizer
from feature_engine.transformation import YeoJohnsonTransformer
from sklearn.preprocessing import StandardScaler
import os

import warnings
warnings.filterwarnings('ignore')

# Suppress TensorFlow logs
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %% [markdown]
# # 1. Reading Clean Dataset:

# %%
merged_df = pd.read_csv('./3-DNN_Baseline/V2-merged_df_noOutliers.csv')
merged_df.head(2)
# Out:
#         cid                                     Smiles  Standard Value  \
# 0  23647975  COc1cc(cc(Cc2cnc(N)nc2N)c1OC)C#CCCCC(O)=O            34.0
# 1      5578            COc1cc(Cc2cnc(N)nc2N)cc(OC)c1OC          2722.0
#
#    pIC50 Value  nAcid   ALogP    ALogp2      AMR       apol  naAromAtom  ...  \
# 0     7.468521      1 -0.9874  0.974959  55.7857  55.717446          12  ...
# 1     5.565112      0 -1.1990  1.437601  34.9926  43.448274          12  ...
#
#      3d-P2s    3d-E1s    3d-E2s    3d-E3s      3d-Ts       3d-As      3d-Vs  \
# 0  0.270792  0.568703  0.404621  0.409698  22.863896  123.556813  272.29810
# 1  0.223644  0.526743  0.420964  0.415681  15.650156   58.403017  129.62338
#
#       3d-Ks     3d-Ds  QT-pIC50 Value
# 0  0.506905  1.383022        0.624900
# 1  0.521793  1.363389       -0.538272
#
# [2 rows x 2761 columns]

# %%
merged_df.shape
# Out:
# (873, 2761)

# %% [markdown]
# # 2. Important features only

# %% [markdown]
# ## 2.1. Reading file with Importance of the Descriptors

# %%
df_imp = pd.read_csv('./5-Feature_Importance/V2-feature_importance_model_PermImp.csv')
df_imp.head(2)
# Out:
#         Feature  Importance
# 0  PubchemFP461    0.009318
# 1  PubchemFP755    0.006300

# %%
df_imp.shape
# Out:
# (1858, 2)

# %% [markdown]
# ## 2.2. Selecting All Features with positive contribution:

# %%
df_imp_pos = df_imp[df_imp['Importance']>0]
df_imp_pos.shape[0]
# Out:
# 1030

# %%
df_imp_pos['Importance'].min()
# Out:
# 1.0001948053228738e-06

# %%
df_imp_pos['Importance'].max()
# Out:
# 0.0093179311212038

# %%
features_all_pos = df_imp_pos['Feature'].to_list()

# %%
len(features_all_pos)
# Out:
# 1030

# %% [markdown]
# ## 2.3. Positive Features by Groups:
#
# #### Grouping Features buy Importance and Analyze:

# %%
import pandas as pd

# Define the new bin edges based on the new interval
bins = [1e-06, 1e-05, 1e-04, 1e-03, 1e-02]

# Reverse the order of the labels to match the bins
labels = [f"Group_{i+1}" for i in range(len(bins) - 1)][::-1]

# Create the 'Group' column using pd.cut with the new bins and labels
df_imp_pos['Group'] = pd.cut(df_imp_pos['Importance'], bins=bins, labels=labels, right=False)

# Display the DataFrame with the new 'Group' column
df_imp_pos.head()
# Out:
#            Feature  Importance    Group
# 0     PubchemFP461    0.009318  Group_1
# 1     PubchemFP755    0.006300  Group_1
# 2           maxsBr    0.004837  Group_1
# 3  nFG12HeteroRing    0.003928  Group_1
# 4        nFG12Ring    0.003861  Group_1

# %%
# Filter data for Group_1
features_Group_1 = df_imp_pos[df_imp_pos['Group'] == 'Group_1']
features_Group_2 = df_imp_pos[df_imp_pos['Group'] == 'Group_2']
features_Group_3 = df_imp_pos[df_imp_pos['Group'] == 'Group_3']
features_Group_4 = df_imp_pos[df_imp_pos['Group'] == 'Group_4']
#features_Group_5 = df_imp_pos[df_imp_pos['Group'] == 'Group_5']

# %%
features_Group_1_arr = features_Group_1['Feature'].to_list()
features_Group_2_arr = features_Group_2['Feature'].to_list()
features_Group_3_arr = features_Group_3['Feature'].to_list()
features_Group_4_arr = features_Group_4['Feature'].to_list()
#features_Group_5_arr = features_Group_5['Feature'].to_list()

# %% [markdown]
# # 3. Groups: 1,2,3,4
# (all positive features)

# %% [markdown]
# ## 3.1. Splitting Data

# %%
# Reset Indexes:
merged_df = merged_df.reset_index(drop=True)

# %%
# FOR MODEL

feat_imp = features_Group_1_arr + features_Group_2_arr + features_Group_3_arr + features_Group_4_arr

X = merged_df[feat_imp]
y = merged_df['pIC50 Value']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state = 42)

# %% [markdown]
# ## 3.2. Missing Data Imputation

# %%
# Initialize the imputer with median imputation method
imputer = MeanMedianImputer(imputation_method='median')

# Fit the imputer to the training data
imputer.fit(X_train)

# Transform the training data
X_train = imputer.transform(X_train)
X_test = imputer.transform(X_test)

# %% [markdown]
# ## 3.3. Removing Constants and Dublicated

# %%
# %%time

# Drop constant
drop_const = DropConstantFeatures(tol=0.999)

drop_const.fit(X_train)
X_train = drop_const.transform(X_train)
X_test = drop_const.transform(X_test)

print(X_train.shape)

# Drop duplicates
drop_dup = DropDuplicateFeatures()

drop_dup.fit(X_train)
X_train = drop_dup.transform(X_train)
X_test = drop_dup.transform(X_test)

print(X_train.shape)
# Out:
# (742, 1030)
# (742, 1030)
# CPU times: user 388 ms, sys: 8.01 ms, total: 396 ms
# Wall time: 397 ms

# %% [markdown]
# ## 3.4. Outliers

# %%
# %time

# Initialize Winsorizer transformer
winsorizer = Winsorizer(capping_method='gaussian', tail='both')

# Fit and transform on training data
winsorizer.fit(X_train)

X_train = winsorizer.transform(X_train)
X_test = winsorizer.transform(X_test)
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 9.54 µs

# %% [markdown]
# ## 3.5. YeoJohnsonTransformer:

# %%
# %time

from feature_engine.transformation import YeoJohnsonTransformer

#Randomly sample 3736 rows from df_t25
yeo_trans = YeoJohnsonTransformer()
yeo_trans.fit(X_train)

X_train = yeo_trans.transform(X_train)
X_test = yeo_trans.transform(X_test)
# Out:
# CPU times: user 6 µs, sys: 0 ns, total: 6 µs
# Wall time: 10.3 µs

# %% [markdown]
# ## 3.6. Scaling:

# %%
# %time

import pandas as pd
from sklearn.preprocessing import StandardScaler

# Instantiate the StandardScaler
scaler = StandardScaler()

# Fit and transform on the training data
scaler.fit(X_train)

# Scale the training data
X_train_eda = scaler.transform(X_train)
X_test_eda = scaler.transform(X_test)

# Convert the numpy arrays back to DataFrames and assign column names
X_train = pd.DataFrame(X_train_eda, columns=X_train.columns)
X_test = pd.DataFrame(X_test_eda, columns=X_test.columns)
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 11 µs

# %% [markdown]
# ## 3.7. Multiple ANN Model (Average of 5 runs)

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from sklearn.metrics import r2_score, mean_absolute_error

# Initialize variables to store results
y_preds = []
maes = []
r2_scores = []

# Run the model 5 times
for i in range(5):
    print(f"Running model {i + 1}")
    # Define the neural network model
    model_1 = Sequential([
        Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
        BatchNormalization(),
        Dropout(0.4),
        Dense(64, activation='relu'),
        BatchNormalization(),
        Dropout(0.3),
        Dense(32, activation='relu'),
        BatchNormalization(),
        Dropout(0.2),
        Dense(16, activation='relu'),
        BatchNormalization(),
        Dense(1, activation='linear')
    ])

    # Compile the model
    optimizer = Adam(learning_rate=0.0007)
    model_1.compile(
        optimizer=optimizer,
        loss='mean_squared_error',
        metrics=['mae']
    )

    # Apply learning rate reduction on plateau
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=20, min_lr=0.000001)

    # Define the EarlyStopping callback
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=30,
        restore_best_weights=True
    )

    # Train the model
    history_improved = model_1.fit(
        X_train,
        y_train,
        batch_size=32,
        epochs=200,  # Reduced to 10 epochs for quicker testing
        validation_data=(X_test, y_test),
        shuffle=True,
        verbose=0,
        callbacks=[reduce_lr, early_stopping]
    )

    # Predict on the test set
    y_pred = model_1.predict(X_test)
    y_preds.append(y_pred.flatten())

    # Calculate MAE and R^2
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    # Append MAE and R^2 to lists
    maes.append(mae)
    r2_scores.append(r2)

    # Delete the model to free up memory before the next iteration
    del model_1

# Convert y_preds list to a DataFrame
y_preds_df = pd.DataFrame(y_preds).T
y_preds_df.columns = [f'y_pred_run_{i+1}' for i in range(5)]
y_preds_df.index = y_test.index  # Use the same index as y_test

# Calculate the average y_pred across all runs
y_preds_df['average_y_pred'] = y_preds_df.mean(axis=1)

# Add y_test to the DataFrame
y_preds_df['y_test'] = y_test

# Calculate MAE and R^2 for the average predictions
average_mae = mean_absolute_error(y_test, y_preds_df['average_y_pred'])
average_r2 = r2_score(y_test, y_preds_df['average_y_pred'])

# Create a summary DataFrame
summary_df = pd.DataFrame({
    'Run': [f'Run {i+1}' for i in range(5)] + ['Average'],
    'R2': r2_scores + [average_r2],
    'MAE': maes + [average_mae]
})
# Out:
# Running model 1
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Running model 2
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Running model 3
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Running model 4
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Running model 5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
y_preds_df.head(10)
# Out:
#      y_pred_run_1  y_pred_run_2  y_pred_run_3  y_pred_run_4  y_pred_run_5  \
# 795      7.864709      7.536908      7.472138      7.134642      7.787519
# 319      5.463920      5.294245      5.503187      5.683762      5.322797
# 382      7.298016      7.409103      7.361859      7.250291      7.717104
# 737      5.562703      5.488126      5.397657      4.962770      5.530093
# 422      6.200253      6.570621      6.187783      5.953372      6.441788
# 327      6.902622      6.527986      6.561361      6.150150      6.651978
# 804      7.262891      7.498817      7.216946      7.115431      7.116826
# 136      7.833560      7.964170      7.612106      7.396597      8.061784
# 670      4.997532      5.332088      5.234408      4.505933      4.622484
# 777      4.336838      4.700521      4.763724      4.963969      4.859804
#
#      average_y_pred    y_test
# 795        7.559184  7.886057
# 319        5.453582  5.769551
# 382        7.407275  7.244125
# 737        5.388270  5.387216
# 422        6.270763  6.008774
# 327        6.558820  6.853872
# 804        7.242182  7.000000
# 136        7.773643  8.698970
# 670        4.938489  4.812479
# 777        4.724971  4.158641

# %%
summary_df
# Out:
#        Run        R2       MAE
# 0    Run 1  0.821752  0.391885
# 1    Run 2  0.802478  0.412485
# 2    Run 3  0.812791  0.408814
# 3    Run 4  0.691885  0.547662
# 4    Run 5  0.780363  0.436040
# 5  Average  0.816039  0.404029

# %% [markdown]
# ## 3.8. Saveing Output:

# %%
y_preds_df['Relative_Error_%'] = (y_preds_df['average_y_pred'] - y_preds_df['y_test'])/y_preds_df['y_test'] * 100
y_preds_df.head()
# Out:
#      y_pred_run_1  y_pred_run_2  y_pred_run_3  y_pred_run_4  y_pred_run_5  \
# 795      7.864709      7.536908      7.472138      7.134642      7.787519
# 319      5.463920      5.294245      5.503187      5.683762      5.322797
# 382      7.298016      7.409103      7.361859      7.250291      7.717104
# 737      5.562703      5.488126      5.397657      4.962770      5.530093
# 422      6.200253      6.570621      6.187783      5.953372      6.441788
#
#      average_y_pred    y_test  Relative_Error_%
# 795        7.559184  7.886057         -4.144949
# 319        5.453582  5.769551         -5.476488
# 382        7.407275  7.244125          2.252164
# 737        5.388270  5.387216          0.019560
# 422        6.270763  6.008774          4.360115

# %%
import matplotlib.pyplot as plt
import numpy as np

# Creating the scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(y_preds_df['y_test'], y_preds_df['average_y_pred'], color='blue', label='Predicted vs True')

# Adding the red line representing the ideal case (y = x)
min_val = min(y_preds_df['y_test'].min(), y_preds_df['average_y_pred'].min())
max_val = max(y_preds_df['y_test'].max(), y_preds_df['average_y_pred'].max())
plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--', label='Ideal')

# Limiting the y-axis to the range [4, 9]
plt.ylim(4, 9)

# Adding title, labels, grid, and legend
plt.title('Scatter Plot of True Values vs Predicted Values')
plt.xlabel('True Values')
plt.ylabel('Predicted Values')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Save the updated DataFrame to a CSV file
y_preds_df.to_csv('output_model_G1234_avrg.csv', index=False)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

log_target_test = y_preds_df['Relative_Error_%']

# Increase the width of the figure to make the plot wider
plt.figure(figsize=(4, 6))

# Create the box plot with adjusted box width and frame thickness
box = plt.boxplot([log_target_test], 
                  vert=True, patch_artist=True, widths=0.6,  # Increase the box width
                  boxprops=dict(facecolor='none', color='darkblue', linewidth=1),  # Thinner box frame
                  medianprops=dict(color='darkblue', linewidth=1.5), 
                  whiskerprops=dict(color='darkblue', linewidth=1.5),
                  capprops=dict(color='darkblue', linewidth=1.5), 
                  flierprops=dict(marker='o', color='red', alpha=0.5))

# Change the color of the box
colors = ['#a6d854']
for box_patch, color in zip(box['boxes'], colors):
    box_patch.set(facecolor=color, alpha=0.6)

# Add grid lines
plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)

# Add a title and labels with custom font sizes
plt.title('Box Plot of Relative Error (%)', fontsize=20, weight='bold')
plt.ylabel('Relative Error (%)', fontsize=18, weight='bold')
plt.xticks([1], ['Target (pIC50)'], fontsize=18, weight='bold')

# Adding median value as text, positioned above the box plot
median = box['medians'][0].get_ydata()[0]
plt.text(1, median + 2, f'{median:.2f}', horizontalalignment='center', color='darkblue', weight='semibold', va='center', fontsize=16)

# Enhance the appearance of the plot
plt.tick_params(axis='both', which='major', labelsize=14)
plt.ylim(-60, 60)  # Set y-axis limit
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# # 4. Groups: 1,2,3

# %% [markdown]
# ## 4.1. Splitting Data

# %%
# Reset Indexes:
merged_df = merged_df.reset_index(drop=True)

# %%
# FOR MODEL

feat_imp = features_Group_1_arr + features_Group_2_arr + features_Group_3_arr 

X = merged_df[feat_imp]
y = merged_df['pIC50 Value']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state = 42)

# %% [markdown]
# ## 4.2. Missing Data Imputation

# %%
# Initialize the imputer with median imputation method
imputer = MeanMedianImputer(imputation_method='median')

# Fit the imputer to the training data
imputer.fit(X_train)

# Transform the training data
X_train = imputer.transform(X_train)
X_test = imputer.transform(X_test)

# %% [markdown]
# ## 4.3. Removing Constants and Dublicated

# %%
# %%time

# Drop constant
drop_const = DropConstantFeatures(tol=0.999)

drop_const.fit(X_train)
X_train = drop_const.transform(X_train)
X_test = drop_const.transform(X_test)

print(X_train.shape)

# Drop duplicates
drop_dup = DropDuplicateFeatures()

drop_dup.fit(X_train)
X_train = drop_dup.transform(X_train)
X_test = drop_dup.transform(X_test)

print(X_train.shape)
# Out:
# (742, 1020)
# (742, 1020)
# CPU times: user 372 ms, sys: 3.01 ms, total: 375 ms
# Wall time: 377 ms

# %% [markdown]
# ## 4.4. Outliers

# %%
# %time

# Initialize Winsorizer transformer
winsorizer = Winsorizer(capping_method='gaussian', tail='both')

# Fit and transform on training data
winsorizer.fit(X_train)

X_train = winsorizer.transform(X_train)
X_test = winsorizer.transform(X_test)
# Out:
# CPU times: user 6 µs, sys: 0 ns, total: 6 µs
# Wall time: 10.7 µs

# %% [markdown]
# ## 4.5. YeoJohnsonTransformer:

# %%
# %time

from feature_engine.transformation import YeoJohnsonTransformer

yeo_trans = YeoJohnsonTransformer()
yeo_trans.fit(X_train)

X_train = yeo_trans.transform(X_train)
X_test = yeo_trans.transform(X_test)
# Out:
# CPU times: user 6 µs, sys: 1e+03 ns, total: 7 µs
# Wall time: 11.4 µs

# %% [markdown]
# ## 4.6. Scaling:

# %%
# %time

import pandas as pd
from sklearn.preprocessing import StandardScaler

# Instantiate the StandardScaler
scaler = StandardScaler()

# Fit and transform on the training data
scaler.fit(X_train)

# Scale the training data
X_train_eda = scaler.transform(X_train)
X_test_eda = scaler.transform(X_test)

# Convert the numpy arrays back to DataFrames and assign column names
X_train = pd.DataFrame(X_train_eda, columns=X_train.columns)
X_test = pd.DataFrame(X_test_eda, columns=X_test.columns)
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 10.5 µs

# %% [markdown]
# ## 4.7. Multiple ANN Model (Average of 5 runs)

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from sklearn.metrics import r2_score, mean_absolute_error

# Initialize variables to store results
y_preds = []
maes = []
r2_scores = []

# Run the model 5 times
for i in range(5):
    print(f"Running model {i + 1}")
    # Define the neural network model
    model_1 = Sequential([
        Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
        BatchNormalization(),
        Dropout(0.4),
        Dense(64, activation='relu'),
        BatchNormalization(),
        Dropout(0.3),
        Dense(32, activation='relu'),
        BatchNormalization(),
        Dropout(0.2),
        Dense(16, activation='relu'),
        BatchNormalization(),
        Dense(1, activation='linear')
    ])

    # Compile the model
    optimizer = Adam(learning_rate=0.0007)
    model_1.compile(
        optimizer=optimizer,
        loss='mean_squared_error',
        metrics=['mae']
    )

    # Apply learning rate reduction on plateau
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=20, min_lr=0.000001)

    # Define the EarlyStopping callback
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=30,
        restore_best_weights=True
    )

    # Train the model
    history_improved = model_1.fit(
        X_train,
        y_train,
        batch_size=32,
        epochs=200,  # Reduced to 10 epochs for quicker testing
        validation_data=(X_test, y_test),
        shuffle=True,
        verbose=0,
        callbacks=[reduce_lr, early_stopping]
    )

    # Predict on the test set
    y_pred = model_1.predict(X_test)
    y_preds.append(y_pred.flatten())

    # Calculate MAE and R^2
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    # Append MAE and R^2 to lists
    maes.append(mae)
    r2_scores.append(r2)

    # Delete the model to free up memory before the next iteration
    del model_1

# Convert y_preds list to a DataFrame
y_preds_df = pd.DataFrame(y_preds).T
y_preds_df.columns = [f'y_pred_run_{i+1}' for i in range(5)]
y_preds_df.index = y_test.index  # Use the same index as y_test

# Calculate the average y_pred across all runs
y_preds_df['average_y_pred'] = y_preds_df.mean(axis=1)

# Add y_test to the DataFrame
y_preds_df['y_test'] = y_test

# Calculate MAE and R^2 for the average predictions
average_mae = mean_absolute_error(y_test, y_preds_df['average_y_pred'])
average_r2 = r2_score(y_test, y_preds_df['average_y_pred'])

# Create a summary DataFrame
summary_df = pd.DataFrame({
    'Run': [f'Run {i+1}' for i in range(5)] + ['Average'],
    'R2': r2_scores + [average_r2],
    'MAE': maes + [average_mae]
})
# Out:
# Running model 1
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Running model 2
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Running model 3
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Running model 4
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Running model 5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
y_preds_df.head(10)
# Out:
#      y_pred_run_1  y_pred_run_2  y_pred_run_3  y_pred_run_4  y_pred_run_5  \
# 795      7.660323      7.463790      7.686842      7.526644      7.727901
# 319      5.153248      5.370785      5.440676      5.201054      5.080816
# 382      7.435030      7.003176      7.371014      7.403513      7.283821
# 737      5.365249      5.526659      5.672641      5.213118      5.397713
# 422      6.346160      6.371481      6.450902      6.042675      6.381277
# 327      6.349447      6.453548      7.010190      6.793687      6.337208
# 804      7.310251      7.412819      7.338616      7.014097      7.494243
# 136      8.225918      7.892373      7.714741      7.814588      7.963794
# 670      4.900016      5.128089      4.931299      4.890344      4.868749
# 777      4.636598      4.612213      4.578336      4.779884      4.815301
#
#      average_y_pred    y_test
# 795        7.613100  7.886057
# 319        5.249316  5.769551
# 382        7.299310  7.244125
# 737        5.435076  5.387216
# 422        6.318500  6.008774
# 327        6.588816  6.853872
# 804        7.314005  7.000000
# 136        7.922282  8.698970
# 670        4.943700  4.812479
# 777        4.684466  4.158641

# %%
summary_df
# Out:
#        Run        R2       MAE
# 0    Run 1  0.797854  0.413090
# 1    Run 2  0.793434  0.422288
# 2    Run 3  0.808014  0.395623
# 3    Run 4  0.797153  0.418845
# 4    Run 5  0.793959  0.425335
# 5  Average  0.815310  0.397893

# %% [markdown]
# ## 4.8. Saveing Output:

# %%
y_preds_df['Relative_Error_%'] = (y_preds_df['average_y_pred'] - y_preds_df['y_test'])/y_preds_df['y_test'] * 100
y_preds_df.head()
# Out:
#      y_pred_run_1  y_pred_run_2  y_pred_run_3  y_pred_run_4  y_pred_run_5  \
# 795      7.660323      7.463790      7.686842      7.526644      7.727901
# 319      5.153248      5.370785      5.440676      5.201054      5.080816
# 382      7.435030      7.003176      7.371014      7.403513      7.283821
# 737      5.365249      5.526659      5.672641      5.213118      5.397713
# 422      6.346160      6.371481      6.450902      6.042675      6.381277
#
#      average_y_pred    y_test  Relative_Error_%
# 795        7.613100  7.886057         -3.461262
# 319        5.249316  5.769551         -9.016912
# 382        7.299310  7.244125          0.761791
# 737        5.435076  5.387216          0.888392
# 422        6.318500  6.008774          5.154556

# %%
import matplotlib.pyplot as plt
import numpy as np

# Creating the scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(y_preds_df['y_test'], y_preds_df['average_y_pred'], color='blue', label='Predicted vs True')

# Adding the red line representing the ideal case (y = x)
min_val = min(y_preds_df['y_test'].min(), y_preds_df['average_y_pred'].min())
max_val = max(y_preds_df['y_test'].max(), y_preds_df['average_y_pred'].max())
plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--', label='Ideal')

# Limiting the y-axis to the range [4, 9]
plt.ylim(4, 9)

# Adding title, labels, grid, and legend
plt.title('Scatter Plot of True Values vs Predicted Values')
plt.xlabel('True Values')
plt.ylabel('Predicted Values')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Save the updated DataFrame to a CSV file
y_preds_df.to_csv('output_model_G123_avrg.csv', index=False)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

log_target_test = y_preds_df['Relative_Error_%']

# Increase the width of the figure to make the plot wider
plt.figure(figsize=(4, 6))

# Create the box plot with adjusted box width and frame thickness
box = plt.boxplot([log_target_test], 
                  vert=True, patch_artist=True, widths=0.6,  # Increase the box width
                  boxprops=dict(facecolor='none', color='darkblue', linewidth=1),  # Thinner box frame
                  medianprops=dict(color='darkblue', linewidth=1.5), 
                  whiskerprops=dict(color='darkblue', linewidth=1.5),
                  capprops=dict(color='darkblue', linewidth=1.5), 
                  flierprops=dict(marker='o', color='red', alpha=0.5))

# Change the color of the box
colors = ['#a6d854']
for box_patch, color in zip(box['boxes'], colors):
    box_patch.set(facecolor=color, alpha=0.6)

# Add grid lines
plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)

# Add a title and labels with custom font sizes
plt.title('Box Plot of Relative Error (%)', fontsize=20, weight='bold')
plt.ylabel('Relative Error (%)', fontsize=18, weight='bold')
plt.xticks([1], ['Target (pIC50)'], fontsize=18, weight='bold')

# Adding median value as text, positioned above the box plot
median = box['medians'][0].get_ydata()[0]
plt.text(1, median + 2, f'{median:.2f}', horizontalalignment='center', color='darkblue', weight='semibold', va='center', fontsize=16)

# Enhance the appearance of the plot
plt.tick_params(axis='both', which='major', labelsize=14)
plt.ylim(-60, 60)  # Set y-axis limit
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# # 5. Groups: 1,2

# %% [markdown]
# ## 5.1. Splitting Data

# %%
# Reset Indexes:
merged_df = merged_df.reset_index(drop=True)

# %%
# FOR MODEL

feat_imp = features_Group_1_arr + features_Group_2_arr 

X = merged_df[feat_imp]
y = merged_df['pIC50 Value']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state = 42)

# %% [markdown]
# ## 5.2. Missing Data Imputation

# %%
# Initialize the imputer with median imputation method
imputer = MeanMedianImputer(imputation_method='median')

# Fit the imputer to the training data
imputer.fit(X_train)

# Transform the training data
X_train = imputer.transform(X_train)
X_test = imputer.transform(X_test)

# %% [markdown]
# ## 5.3. Removing Constants and Dublicated

# %%
# %%time

# Drop constant
drop_const = DropConstantFeatures(tol=0.999)

drop_const.fit(X_train)
X_train = drop_const.transform(X_train)
X_test = drop_const.transform(X_test)

print(X_train.shape)

# Drop duplicates
drop_dup = DropDuplicateFeatures()

drop_dup.fit(X_train)
X_train = drop_dup.transform(X_train)
X_test = drop_dup.transform(X_test)

print(X_train.shape)
# Out:
# (742, 909)
# (742, 909)
# CPU times: user 340 ms, sys: 2.97 ms, total: 343 ms
# Wall time: 344 ms

# %% [markdown]
# ## 5.4. Outliers

# %%
# %time

# Initialize Winsorizer transformer
winsorizer = Winsorizer(capping_method='gaussian', tail='both')

# Fit and transform on training data
winsorizer.fit(X_train)

X_train = winsorizer.transform(X_train)
X_test = winsorizer.transform(X_test)
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 10.3 µs

# %% [markdown]
# ## 5.5. YeoJohnsonTransformer:

# %%
# %time

from feature_engine.transformation import YeoJohnsonTransformer

yeo_trans = YeoJohnsonTransformer()
yeo_trans.fit(X_train)

X_train = yeo_trans.transform(X_train)
X_test = yeo_trans.transform(X_test)
# Out:
# CPU times: user 6 µs, sys: 0 ns, total: 6 µs
# Wall time: 11 µs

# %% [markdown]
# ## 5.6. Scaling:

# %%
# %time

import pandas as pd
from sklearn.preprocessing import StandardScaler

# Instantiate the StandardScaler
scaler = StandardScaler()

# Fit and transform on the training data
scaler.fit(X_train)

# Scale the training data
X_train_eda = scaler.transform(X_train)
X_test_eda = scaler.transform(X_test)

# Convert the numpy arrays back to DataFrames and assign column names
X_train = pd.DataFrame(X_train_eda, columns=X_train.columns)
X_test = pd.DataFrame(X_test_eda, columns=X_test.columns)
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 10.7 µs

# %% [markdown]
# ## 5.7. Multiple ANN Model (Average of 5 runs)

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from sklearn.metrics import r2_score, mean_absolute_error

# Initialize variables to store results
y_preds = []
maes = []
r2_scores = []

# Run the model 5 times
for i in range(5):
    print(f"Running model {i + 1}")
    # Define the neural network model
    model_1 = Sequential([
        Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
        BatchNormalization(),
        Dropout(0.4),
        Dense(64, activation='relu'),
        BatchNormalization(),
        Dropout(0.3),
        Dense(32, activation='relu'),
        BatchNormalization(),
        Dropout(0.2),
        Dense(16, activation='relu'),
        BatchNormalization(),
        Dense(1, activation='linear')
    ])

    # Compile the model
    optimizer = Adam(learning_rate=0.0007)
    model_1.compile(
        optimizer=optimizer,
        loss='mean_squared_error',
        metrics=['mae']
    )

    # Apply learning rate reduction on plateau
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=20, min_lr=0.000001)

    # Define the EarlyStopping callback
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=30,
        restore_best_weights=True
    )

    # Train the model
    history_improved = model_1.fit(
        X_train,
        y_train,
        batch_size=32,
        epochs=200,  # Reduced to 10 epochs for quicker testing
        validation_data=(X_test, y_test),
        shuffle=True,
        verbose=0,
        callbacks=[reduce_lr, early_stopping]
    )

    # Predict on the test set
    y_pred = model_1.predict(X_test)
    y_preds.append(y_pred.flatten())

    # Calculate MAE and R^2
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    # Append MAE and R^2 to lists
    maes.append(mae)
    r2_scores.append(r2)

    # Delete the model to free up memory before the next iteration
    del model_1

# Convert y_preds list to a DataFrame
y_preds_df = pd.DataFrame(y_preds).T
y_preds_df.columns = [f'y_pred_run_{i+1}' for i in range(5)]
y_preds_df.index = y_test.index  # Use the same index as y_test

# Calculate the average y_pred across all runs
y_preds_df['average_y_pred'] = y_preds_df.mean(axis=1)

# Add y_test to the DataFrame
y_preds_df['y_test'] = y_test

# Calculate MAE and R^2 for the average predictions
average_mae = mean_absolute_error(y_test, y_preds_df['average_y_pred'])
average_r2 = r2_score(y_test, y_preds_df['average_y_pred'])

# Create a summary DataFrame
summary_df = pd.DataFrame({
    'Run': [f'Run {i+1}' for i in range(5)] + ['Average'],
    'R2': r2_scores + [average_r2],
    'MAE': maes + [average_mae]
})
# Out:
# Running model 1
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Running model 2
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Running model 3
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Running model 4
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Running model 5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
y_preds_df.head(10)
# Out:
#      y_pred_run_1  y_pred_run_2  y_pred_run_3  y_pred_run_4  y_pred_run_5  \
# 795      7.709640      7.518972      7.644924      7.631299      7.665178
# 319      5.621986      5.264903      5.260285      5.321470      5.267072
# 382      7.483162      7.346616      7.327475      7.507686      7.287429
# 737      5.248728      5.477678      5.627798      5.351416      5.439092
# 422      6.349343      6.140395      6.334160      6.378543      6.222704
# 327      6.608490      7.212407      6.890930      6.525434      6.659278
# 804      7.277162      7.378919      7.086671      7.554286      7.427240
# 136      8.198147      7.853248      7.961055      7.929701      7.961695
# 670      4.976768      4.976530      5.358326      5.085005      5.146038
# 777      5.103806      4.750545      4.431889      4.862212      4.759891
#
#      average_y_pred    y_test
# 795        7.634003  7.886057
# 319        5.347144  5.769551
# 382        7.390474  7.244125
# 737        5.428942  5.387216
# 422        6.285029  6.008774
# 327        6.779307  6.853872
# 804        7.344856  7.000000
# 136        7.980769  8.698970
# 670        5.108533  4.812479
# 777        4.781669  4.158641

# %%
summary_df
# Out:
#        Run        R2       MAE
# 0    Run 1  0.746830  0.463032
# 1    Run 2  0.790840  0.420727
# 2    Run 3  0.804056  0.405116
# 3    Run 4  0.791543  0.439086
# 4    Run 5  0.815709  0.405801
# 5  Average  0.811684  0.396184

# %% [markdown]
# ## 5.8. Saveing Output:

# %%
y_preds_df['Relative_Error_%'] = (y_preds_df['average_y_pred'] - y_preds_df['y_test'])/y_preds_df['y_test'] * 100
y_preds_df.head()
# Out:
#      y_pred_run_1  y_pred_run_2  y_pred_run_3  y_pred_run_4  y_pred_run_5  \
# 795      7.709640      7.518972      7.644924      7.631299      7.665178
# 319      5.621986      5.264903      5.260285      5.321470      5.267072
# 382      7.483162      7.346616      7.327475      7.507686      7.287429
# 737      5.248728      5.477678      5.627798      5.351416      5.439092
# 422      6.349343      6.140395      6.334160      6.378543      6.222704
#
#      average_y_pred    y_test  Relative_Error_%
# 795        7.634003  7.886057         -3.196198
# 319        5.347144  5.769551         -7.321322
# 382        7.390474  7.244125          2.020240
# 737        5.428942  5.387216          0.774538
# 422        6.285029  6.008774          4.597535

# %%
import matplotlib.pyplot as plt
import numpy as np

# Creating the scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(y_preds_df['y_test'], y_preds_df['average_y_pred'], color='blue', label='Predicted vs True')

# Adding the red line representing the ideal case (y = x)
min_val = min(y_preds_df['y_test'].min(), y_preds_df['average_y_pred'].min())
max_val = max(y_preds_df['y_test'].max(), y_preds_df['average_y_pred'].max())
plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--', label='Ideal')

# Limiting the y-axis to the range [4, 9]
plt.ylim(4, 9)

# Adding title, labels, grid, and legend
plt.title('Scatter Plot of True Values vs Predicted Values')
plt.xlabel('True Values')
plt.ylabel('Predicted Values')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Save the updated DataFrame to a CSV file
y_preds_df.to_csv('output_model_G12_avrg.csv', index=False)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

log_target_test = y_preds_df['Relative_Error_%']

# Increase the width of the figure to make the plot wider
plt.figure(figsize=(4, 6))

# Create the box plot with adjusted box width and frame thickness
box = plt.boxplot([log_target_test], 
                  vert=True, patch_artist=True, widths=0.6,  # Increase the box width
                  boxprops=dict(facecolor='none', color='darkblue', linewidth=1),  # Thinner box frame
                  medianprops=dict(color='darkblue', linewidth=1.5), 
                  whiskerprops=dict(color='darkblue', linewidth=1.5),
                  capprops=dict(color='darkblue', linewidth=1.5), 
                  flierprops=dict(marker='o', color='red', alpha=0.5))

# Change the color of the box
colors = ['#a6d854']
for box_patch, color in zip(box['boxes'], colors):
    box_patch.set(facecolor=color, alpha=0.6)

# Add grid lines
plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)

# Add a title and labels with custom font sizes
plt.title('Box Plot of Relative Error (%)', fontsize=20, weight='bold')
plt.ylabel('Relative Error (%)', fontsize=18, weight='bold')
plt.xticks([1], ['Target (pIC50)'], fontsize=18, weight='bold')

# Adding median value as text, positioned above the box plot
median = box['medians'][0].get_ydata()[0]
plt.text(1, median + 2, f'{median:.2f}', horizontalalignment='center', color='darkblue', weight='semibold', va='center', fontsize=16)

# Enhance the appearance of the plot
plt.tick_params(axis='both', which='major', labelsize=14)
plt.ylim(-60, 60)  # Set y-axis limit
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# # 6. Groups: 1

# %% [markdown]
# ## 6.1. Splitting Data

# %%
# Reset Indexes:
merged_df = merged_df.reset_index(drop=True)

# %%
# FOR MODEL

feat_imp = features_Group_1_arr 

X = merged_df[feat_imp]
y = merged_df['pIC50 Value']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state = 42)

# %% [markdown]
# ## 6.2. Missing Data Imputation

# %%
# Initialize the imputer with median imputation method
imputer = MeanMedianImputer(imputation_method='median')

# Fit the imputer to the training data
imputer.fit(X_train)

# Transform the training data
X_train = imputer.transform(X_train)
X_test = imputer.transform(X_test)

# %% [markdown]
# ## 6.3. Removing Constants and Dublicated

# %%
# %%time

# Drop constant
drop_const = DropConstantFeatures(tol=0.999)

drop_const.fit(X_train)
X_train = drop_const.transform(X_train)
X_test = drop_const.transform(X_test)

print(X_train.shape)

# Drop duplicates
drop_dup = DropDuplicateFeatures()

drop_dup.fit(X_train)
X_train = drop_dup.transform(X_train)
X_test = drop_dup.transform(X_test)

print(X_train.shape)
# Out:
# (742, 124)
# (742, 124)
# CPU times: user 71.8 ms, sys: 1 ms, total: 72.8 ms
# Wall time: 73 ms

# %% [markdown]
# ## 6.4. Outliers

# %%
# %time

# Initialize Winsorizer transformer
winsorizer = Winsorizer(capping_method='gaussian', tail='both')

# Fit and transform on training data
winsorizer.fit(X_train)

X_train = winsorizer.transform(X_train)
X_test = winsorizer.transform(X_test)
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 10.7 µs

# %% [markdown]
# ## 6.5. YeoJohnsonTransformer:

# %%
# %time

from feature_engine.transformation import YeoJohnsonTransformer

yeo_trans = YeoJohnsonTransformer()
yeo_trans.fit(X_train)

X_train = yeo_trans.transform(X_train)
X_test = yeo_trans.transform(X_test)
# Out:
# CPU times: user 6 µs, sys: 0 ns, total: 6 µs
# Wall time: 11.4 µs

# %% [markdown]
# ## 6.6. Scaling:

# %%
# %time

import pandas as pd
from sklearn.preprocessing import StandardScaler

# Instantiate the StandardScaler
scaler = StandardScaler()

# Fit and transform on the training data
scaler.fit(X_train)

# Scale the training data
X_train_eda = scaler.transform(X_train)
X_test_eda = scaler.transform(X_test)

# Convert the numpy arrays back to DataFrames and assign column names
X_train = pd.DataFrame(X_train_eda, columns=X_train.columns)
X_test = pd.DataFrame(X_test_eda, columns=X_test.columns)
# Out:
# CPU times: user 6 µs, sys: 0 ns, total: 6 µs
# Wall time: 10.5 µs

# %% [markdown]
# ## 6.7. Multiple ANN Model (Average of 5 runs)

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from sklearn.metrics import r2_score, mean_absolute_error

# Initialize variables to store results
y_preds = []
maes = []
r2_scores = []

# Run the model 5 times
for i in range(5):
    print(f"Running model {i + 1}")
    # Define the neural network model
    model_1 = Sequential([
        Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
        BatchNormalization(),
        Dropout(0.4),
        Dense(64, activation='relu'),
        BatchNormalization(),
        Dropout(0.3),
        Dense(32, activation='relu'),
        BatchNormalization(),
        Dropout(0.2),
        Dense(16, activation='relu'),
        BatchNormalization(),
        Dense(1, activation='linear')
    ])

    # Compile the model
    optimizer = Adam(learning_rate=0.0007)
    model_1.compile(
        optimizer=optimizer,
        loss='mean_squared_error',
        metrics=['mae']
    )

    # Apply learning rate reduction on plateau
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=20, min_lr=0.000001)

    # Define the EarlyStopping callback
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=30,
        restore_best_weights=True
    )

    # Train the model
    history_improved = model_1.fit(
        X_train,
        y_train,
        batch_size=32,
        epochs=200,  # Reduced to 10 epochs for quicker testing
        validation_data=(X_test, y_test),
        shuffle=True,
        verbose=0,
        callbacks=[reduce_lr, early_stopping]
    )

    # Predict on the test set
    y_pred = model_1.predict(X_test)
    y_preds.append(y_pred.flatten())

    # Calculate MAE and R^2
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    # Append MAE and R^2 to lists
    maes.append(mae)
    r2_scores.append(r2)

    # Delete the model to free up memory before the next iteration
    del model_1

# Convert y_preds list to a DataFrame
y_preds_df = pd.DataFrame(y_preds).T
y_preds_df.columns = [f'y_pred_run_{i+1}' for i in range(5)]
y_preds_df.index = y_test.index  # Use the same index as y_test

# Calculate the average y_pred across all runs
y_preds_df['average_y_pred'] = y_preds_df.mean(axis=1)

# Add y_test to the DataFrame
y_preds_df['y_test'] = y_test

# Calculate MAE and R^2 for the average predictions
average_mae = mean_absolute_error(y_test, y_preds_df['average_y_pred'])
average_r2 = r2_score(y_test, y_preds_df['average_y_pred'])

# Create a summary DataFrame
summary_df = pd.DataFrame({
    'Run': [f'Run {i+1}' for i in range(5)] + ['Average'],
    'R2': r2_scores + [average_r2],
    'MAE': maes + [average_mae]
})
# Out:
# Running model 1
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Running model 2
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Running model 3
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Running model 4
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Running model 5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
y_preds_df.head(10)
# Out:
#      y_pred_run_1  y_pred_run_2  y_pred_run_3  y_pred_run_4  y_pred_run_5  \
# 795      7.253723      7.428530      7.775692      7.415351      7.632143
# 319      5.161010      4.941776      5.207817      5.225940      4.975024
# 382      7.081151      7.207612      7.066239      7.372579      7.134966
# 737      5.143604      5.593310      5.701962      5.274138      5.436477
# 422      5.696469      6.066250      5.887050      5.448123      5.686545
# 327      6.111561      6.313959      5.867789      5.726102      6.063601
# 804      7.134007      7.529195      7.847942      7.477455      7.374994
# 136      8.042213      7.650677      7.790416      7.430116      7.555274
# 670      6.466106      6.202210      6.146463      6.289918      6.605328
# 777      4.364074      4.395154      4.703980      4.356876      4.394541
#
#      average_y_pred    y_test
# 795        7.501088  7.886057
# 319        5.102313  5.769551
# 382        7.172510  7.244125
# 737        5.429898  5.387216
# 422        5.756887  6.008774
# 327        6.016603  6.853872
# 804        7.472719  7.000000
# 136        7.693739  8.698970
# 670        6.342005  4.812479
# 777        4.442925  4.158641

# %%
summary_df
# Out:
#        Run        R2       MAE
# 0    Run 1  0.755000  0.488473
# 1    Run 2  0.762193  0.470781
# 2    Run 3  0.747148  0.491248
# 3    Run 4  0.740214  0.504996
# 4    Run 5  0.772832  0.463219
# 5  Average  0.781759  0.453873

# %% [markdown]
# ## 6.8. Saveing Output:

# %%
y_preds_df['Relative_Error_%'] = (y_preds_df['average_y_pred'] - y_preds_df['y_test'])/y_preds_df['y_test'] * 100
y_preds_df.head()
# Out:
#      y_pred_run_1  y_pred_run_2  y_pred_run_3  y_pred_run_4  y_pred_run_5  \
# 795      7.253723      7.428530      7.775692      7.415351      7.632143
# 319      5.161010      4.941776      5.207817      5.225940      4.975024
# 382      7.081151      7.207612      7.066239      7.372579      7.134966
# 737      5.143604      5.593310      5.701962      5.274138      5.436477
# 422      5.696469      6.066250      5.887050      5.448123      5.686545
#
#      average_y_pred    y_test  Relative_Error_%
# 795        7.501088  7.886057         -4.881635
# 319        5.102313  5.769551        -11.564817
# 382        7.172510  7.244125         -0.988601
# 737        5.429898  5.387216          0.792285
# 422        5.756887  6.008774         -4.191986

# %%
import matplotlib.pyplot as plt
import numpy as np

# Creating the scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(y_preds_df['y_test'], y_preds_df['average_y_pred'], color='blue', label='Predicted vs True')

# Adding the red line representing the ideal case (y = x)
min_val = min(y_preds_df['y_test'].min(), y_preds_df['average_y_pred'].min())
max_val = max(y_preds_df['y_test'].max(), y_preds_df['average_y_pred'].max())
plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--', label='Ideal')

# Limiting the y-axis to the range [4, 9]
plt.ylim(4, 9)

# Adding title, labels, grid, and legend
plt.title('Scatter Plot of True Values vs Predicted Values')
plt.xlabel('True Values')
plt.ylabel('Predicted Values')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Save the updated DataFrame to a CSV file
y_preds_df.to_csv('output_model_G1_avrg.csv', index=False)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

log_target_test = y_preds_df['Relative_Error_%']

# Increase the width of the figure to make the plot wider
plt.figure(figsize=(4, 6))

# Create the box plot with adjusted box width and frame thickness
box = plt.boxplot([log_target_test], 
                  vert=True, patch_artist=True, widths=0.6,  # Increase the box width
                  boxprops=dict(facecolor='none', color='darkblue', linewidth=1),  # Thinner box frame
                  medianprops=dict(color='darkblue', linewidth=1.5), 
                  whiskerprops=dict(color='darkblue', linewidth=1.5),
                  capprops=dict(color='darkblue', linewidth=1.5), 
                  flierprops=dict(marker='o', color='red', alpha=0.5))

# Change the color of the box
colors = ['#a6d854']
for box_patch, color in zip(box['boxes'], colors):
    box_patch.set(facecolor=color, alpha=0.6)

# Add grid lines
plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)

# Add a title and labels with custom font sizes
plt.title('Box Plot of Relative Error (%)', fontsize=20, weight='bold')
plt.ylabel('Relative Error (%)', fontsize=18, weight='bold')
plt.xticks([1], ['Target (pIC50)'], fontsize=18, weight='bold')

# Adding median value as text, positioned above the box plot
median = box['medians'][0].get_ydata()[0]
plt.text(1, median + 2, f'{median:.2f}', horizontalalignment='center', color='darkblue', weight='semibold', va='center', fontsize=16)

# Enhance the appearance of the plot
plt.tick_params(axis='both', which='major', labelsize=14)
plt.ylim(-60, 60)  # Set y-axis limit
plt.tight_layout()

# Display the plot
plt.show()
